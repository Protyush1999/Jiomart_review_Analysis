# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Creating a pandas dataframe from reviews.excel file
try:
  mydata=pd.read_excel('/content/drive/MyDrive/Jio Mart 204424 Reviews.xlsx')
except Exception:
  pass

# %%
mydata
# Out:
#                                     reviewId           userName  \
# 0       ccb7f28d-32bc-498b-930e-4cc86eea6932        Vivek Lakum
# 1       0a7f0d2a-3815-46d4-bb5a-202db3ab14d8       Liyakath ali
# 2       0a69b1bf-7c98-41c5-b99f-8a761df2bc79      jagjeet singh
# 3       9e13f501-6154-4b85-a7cb-edcf3a82ee42          Pintu Das
# 4       09c540b1-9e6e-4364-a95d-3f2349e91b01       Chirag Puvar
# ...                                      ...                ...
# 204419  90ad7655-9fb6-4a64-bf6e-7e4d20392643     Birendra Kumar
# 204420  a5161eaa-9a6d-4147-8e68-f7eece9ff76e     Beer Mohamed S
# 204421  5240e4af-d586-427b-8180-8f901132f3d1     Pankaj Chhetri
# 204422  a828cd5c-4c79-44ec-9e30-b2b696275c9f  Sumit Vishwakarma
# 204423  453ab2df-0212-4eba-be71-e1b4f5be6a33       John Manjila
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ALm5wu...
# 1       https://play-lh.googleusercontent.com/a-/ACNPE...
# 2       https://play-lh.googleusercontent.com/a/ALm5wu...
# 3       https://play-lh.googleusercontent.com/a/ALm5wu...
# 4       https://play-lh.googleusercontent.com/a-/ACNPE...
# ...                                                   ...
# 204419  https://play-lh.googleusercontent.com/a-/ACNPE...
# 204420  https://play-lh.googleusercontent.com/a-/ACNPE...
# 204421  https://play-lh.googleusercontent.com/a-/ACNPE...
# 204422  https://play-lh.googleusercontent.com/a-/ACNPE...
# 204423  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                                   content  score  \
# 0                                                ❤️❤️❤️❤️      5
# 1                                                good app      5
# 2       Worst experience on the name jio company....i ...      1
# 3       Very bad delivery. Customer care no response. ...      1
# 4                                                    Nice      5
# ...                                                   ...    ...
# 204419                                    Great service 👍      5
# 204420  Its great App. Extremely easy to order and goo...      5
# 204421           Please integrate this app with MYJio app      5
# 204422  Very helpful app, especially during lockdown. ...      5
# 204423               Much awaited, kudos to JioMart team!      5
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 0                   0               1.0.31 2022-10-19 07:16:56
# 1                   0               1.0.31 2022-10-19 07:16:16
# 2                   0               1.0.31 2022-10-19 07:16:01
# 3                   0               1.0.31 2022-10-19 07:14:32
# 4                   0               1.0.31 2022-10-19 07:12:58
# ...               ...                  ...                 ...
# 204419              2          1.0.0-alpha 2020-07-17 05:19:02
# 204420             71          1.0.0-alpha 2020-07-17 04:59:31
# 204421              9                  NaN 2020-07-17 04:54:05
# 204422            314          1.0.0-alpha 2020-07-17 04:44:44
# 204423              5          1.0.0-alpha 2020-07-17 04:43:55
#
#                                              replyContent           repliedAt
# 0                                                     NaN                 NaT
# 1                                                     NaN                 NaT
# 2       Hi jagjeet, We regret for the inconvenience ca... 2022-10-19 07:34:21
# 3       Hi Pintu, We regret the inconvenience caused. ... 2022-10-19 07:27:41
# 4                                                     NaN                 NaT
# ...                                                   ...                 ...
# 204419                                                NaN                 NaT
# 204420                                                NaN                 NaT
# 204421                                                NaN                 NaT
# 204422                                                NaN                 NaT
# 204423                                                NaN                 NaT
#
# [204424 rows x 10 columns]

# %%
mydata = mydata.drop(['reviewId','userImage','thumbsUpCount','reviewCreatedVersion','at','replyContent','repliedAt'],axis=1)
mydata.head()
# Out:
#         userName                                            content  score
# 0    Vivek Lakum                                           ❤️❤️❤️❤️      5
# 1   Liyakath ali                                           good app      5
# 2  jagjeet singh  Worst experience on the name jio company....i ...      1
# 3      Pintu Das  Very bad delivery. Customer care no response. ...      1
# 4   Chirag Puvar                                               Nice      5

# %%
mydata = mydata.dropna(axis=0)
mydata
# Out:
#                  userName                                            content  \
# 0             Vivek Lakum                                           ❤️❤️❤️❤️
# 1            Liyakath ali                                           good app
# 2           jagjeet singh  Worst experience on the name jio company....i ...
# 3               Pintu Das  Very bad delivery. Customer care no response. ...
# 4            Chirag Puvar                                               Nice
# ...                   ...                                                ...
# 204419     Birendra Kumar                                    Great service 👍
# 204420     Beer Mohamed S  Its great App. Extremely easy to order and goo...
# 204421     Pankaj Chhetri           Please integrate this app with MYJio app
# 204422  Sumit Vishwakarma  Very helpful app, especially during lockdown. ...
# 204423       John Manjila               Much awaited, kudos to JioMart team!
#
#         score
# 0           5
# 1           5
# 2           1
# 3           1
# 4           5
# ...       ...
# 204419      5
# 204420      5
# 204421      5
# 204422      5
# 204423      5
#
# [204424 rows x 3 columns]

# %%
import re

# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

def clean1(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^0-9]+', ' ',str(text))
    return text
  

# Cleaning the text in the review column
mydata['Cleaned Reviews'] = mydata['content'].apply(clean)
mydata['cleaned Rating'] = mydata['score'].apply(clean1)
mydata.head()
# Out:
#         userName                                            content  score  \
# 0    Vivek Lakum                                           ❤️❤️❤️❤️      5
# 1   Liyakath ali                                           good app      5
# 2  jagjeet singh  Worst experience on the name jio company....i ...      1
# 3      Pintu Das  Very bad delivery. Customer care no response. ...      1
# 4   Chirag Puvar                                               Nice      5
#
#                                      Cleaned Reviews cleaned Rating
# 0                                                                 5
# 1                                           good app              5
# 2  Worst experience on the name jio company i ord...              1
# 3  Very bad delivery Customer care no response Go...              1
# 4                                               Nice              5

# %%
data = mydata.drop(['content','userName','score'],axis=1)
data.head()
# Out:
#                                      Cleaned Reviews cleaned Rating
# 0                                                                 5
# 1                                           good app              5
# 2  Worst experience on the name jio company i ord...              1
# 3  Very bad delivery Customer care no response Go...              1
# 4                                               Nice              5

# %%
data.drop([0], axis=0, inplace=True)

# %%
data.head()
# Out:
#                                      Cleaned Reviews cleaned Rating
# 1                                           good app              5
# 2  Worst experience on the name jio company i ord...              1
# 3  Very bad delivery Customer care no response Go...              1
# 4                                               Nice              5
# 5                                               good              1

# %%
rating_transform=list()
for i in data["cleaned Rating"]:
  if(int(i)<2):
    i=-1
  elif(int(i)>4):
    i=1
  else:
    i=0
  rating_transform.append(i)

# %%
data["rating_transform"]=rating_transform
data=data.drop("cleaned Rating",axis=1)
data.head()
# Out:
#                                      Cleaned Reviews  rating_transform
# 1                                           good app                 1
# 2  Worst experience on the name jio company i ord...                -1
# 3  Very bad delivery Customer care no response Go...                -1
# 4                                               Nice                 1
# 5                                               good                -1

# %%
data['rating_transform'].value_counts()
# Out:
#  1    96690
# -1    65210
#  0    42523
# Name: rating_transform, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(6, 6))

Count=["96690",'42523','65210']
lables1=['Positive','Neutral','Negative']
ax.pie(Count, labels=lables1, autopct='%.1f%%',
       wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
       textprops={'size': 'x-large'})
ax.set_title('Sentiments', fontsize=18)
plt.tight_layout()

# %% [markdown]
# #Parts of Speech Tag

# %%
import nltk
nltk.download('punkt')
nltk.download('omw-1.4')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')


# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
            newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist

data['POS tagged'] = data['Cleaned Reviews'].apply(token_stop_pos)
data.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
#                                      Cleaned Reviews  rating_transform  \
# 1                                           good app                 1
# 2  Worst experience on the name jio company i ord...                -1
# 3  Very bad delivery Customer care no response Go...                -1
# 4                                               Nice                 1
# 5                                               good                -1
#
#                                           POS tagged
# 1                              [(good, a), (app, n)]
# 2  [(Worst, n), (experience, n), (name, n), (jio,...
# 3  [(bad, a), (delivery, n), (Customer, n), (care...
# 4                                        [(Nice, n)]
# 5                                        [(good, a)]

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos: 
            lemma = word
            lemma_rew = lemma_rew + " " + lemma
        else:  
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
            lemma_rew = lemma_rew + " " + lemma
    return lemma_rew
    
data['Lemma'] =data['POS tagged'].apply(lemmatize)
data.head()
# Out:
#                                      Cleaned Reviews  rating_transform  \
# 1                                           good app                 1
# 2  Worst experience on the name jio company i ord...                -1
# 3  Very bad delivery Customer care no response Go...                -1
# 4                                               Nice                 1
# 5                                               good                -1
#
#                                           POS tagged  \
# 1                              [(good, a), (app, n)]
# 2  [(Worst, n), (experience, n), (name, n), (jio,...
# 3  [(bad, a), (delivery, n), (Customer, n), (care...
# 4                                        [(Nice, n)]
# 5                                        [(good, a)]
#
#                                                Lemma
# 1                                           good app
# 2    Worst experience name jio company order cook...
# 3    bad delivery Customer care response Goods de...
# 4                                               Nice
# 5                                               good

# %% [markdown]
# #Lematization

# %% [markdown]
# # **TextBlob**

# %%
from textblob import TextBlob

# function to calculate subjectivity

def getSubjectivity(Description):
    return TextBlob(Description).sentiment.subjectivity

    # function to calculate polarity

def getPolarity(Description):
    return TextBlob(Description).sentiment.polarity

# function to analyze the reviews
def analysis(score):
    if score <= -0.5:
        return 'Negative'
    elif score >= 0.5:
        return 'Positive'
    else:
        return 'Neutral'

# %%
fin_data = pd.DataFrame(data[['Cleaned Reviews', 'Lemma']])
print(fin_data)
# Out:
#                                           Cleaned Reviews  \
# 1                                                good app
# 2       Worst experience on the name jio company i ord...
# 3       Very bad delivery Customer care no response Go...
# 4                                                    Nice
# 5                                                    good
# ...                                                   ...
# 204419                                     Great service
# 204420  Its great App Extremely easy to order and good...
# 204421           Please integrate this app with MYJio app
# 204422  Very helpful app especially during lockdown On...
# 204423                Much awaited kudos to JioMart team
#
#                                                     Lemma
# 1                                                good app
# 2         Worst experience name jio company order cook...
# 3         bad delivery Customer care response Goods de...
# 4                                                    Nice
# 5                                                    good
# ...                                                   ...
# 204419                                      Great service
# 204420    great App Extremely easy order good shopping...
# 204421                     Please integrate app MYJio app
# 204422    helpful app especially lockdown One buy esse...
# 204423                      Much await kudos JioMart team
#
# [204423 rows x 2 columns]

# %%
fin_data['Lemma']=fin_data['Lemma'].astype(str)

# %%
fin_data['Subjectivity'] = fin_data['Lemma'].apply(getSubjectivity) 
fin_data['Polarity'] = fin_data['Lemma'].apply(getPolarity) 
fin_data['Analysis'] = fin_data['Polarity'].apply(analysis)
fin_data.head()
# Out:
#                                      Cleaned Reviews  \
# 1                                           good app
# 2  Worst experience on the name jio company i ord...
# 3  Very bad delivery Customer care no response Go...
# 4                                               Nice
# 5                                               good
#
#                                                Lemma  Subjectivity  Polarity  \
# 1                                           good app      0.600000       0.7
# 2    Worst experience name jio company order cook...      1.000000      -0.5
# 3    bad delivery Customer care response Goods de...      0.666667      -0.7
# 4                                               Nice      1.000000       0.6
# 5                                               good      0.600000       0.7
#
#    Analysis
# 1  Positive
# 2  Negative
# 3  Negative
# 4  Positive
# 5  Positive

# %%
tb_counts = fin_data.Analysis.value_counts()
tb_counts
# Out:
# Neutral     100066
# Positive     88621
# Negative     15736
# Name: Analysis, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

tb_count= fin_data.Analysis.value_counts()
plt.figure(figsize=(10, 7))
plt.pie(tb_counts.values, labels = tb_counts.index, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
plt.legend()

# %% [markdown]
# # **Sentiment Analysis Using Vader**

# %%
# !pip install vadersentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vadersentiment in /usr/local/lib/python3.7/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vadersentiment) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (1.24.3)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# function to calculate vader sentiment  
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']

fin_data['Vader Sentiment'] = fin_data['Lemma'].apply(vadersentimentanalysis)

# %%
#Vader_Polarity = analyzer.polarity_scores((fin_data['Lemma'].sample(frac=0.25)))
#print(Vader_Polarity)

# %%
# function to analyse 
def vader_analysis(compound):
    if compound >= 0.5:
        return 'Positive'
    elif compound <= -0.5 :
        return 'Negative'
    else:
        return 'Neutral'
    
fin_data['Vader Analysis'] = fin_data['Vader Sentiment'].apply(vader_analysis)
fin_data.head()
# Out:
#                                      Cleaned Reviews  \
# 1                                           good app
# 2  Worst experience on the name jio company i ord...
# 3  Very bad delivery Customer care no response Go...
# 4                                               Nice
# 5                                               good
#
#                                                Lemma  Subjectivity  Polarity  \
# 1                                           good app      0.600000       0.7
# 2    Worst experience name jio company order cook...      1.000000      -0.5
# 3    bad delivery Customer care response Goods de...      0.666667      -0.7
# 4                                               Nice      1.000000       0.6
# 5                                               good      0.600000       0.7
#
#    Analysis  Vader Sentiment Vader Analysis
# 1  Positive           0.4404        Neutral
# 2  Negative          -0.6808       Negative
# 3  Negative          -0.0772        Neutral
# 4  Positive           0.4215        Neutral
# 5  Positive           0.4404        Neutral

# %%
fin_data['Vader Sentiment']
# Out:
# 1         0.4404
# 2        -0.6808
# 3        -0.0772
# 4         0.4215
# 5         0.4404
#            ...
# 204419    0.6249
# 204420    0.8874
# 204421    0.3182
# 204422    0.6613
# 204423    0.5719
# Name: Vader Sentiment, Length: 204423, dtype: float64

# %%
vader_counts = fin_data['Vader Analysis'].value_counts()
vader_counts
# Out:
# Neutral     130980
# Positive     47224
# Negative     26219
# Name: Vader Analysis, dtype: int64

# %%
vader_counts= fin_data['Vader Analysis'].value_counts()
plt.figure(figsize=(10, 7))
plt.pie(vader_counts.values, labels = vader_counts.index, explode = (0.1, 0, 0), autopct='%1.1f%%', shadow=False)
# plt.legend()
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcfee11fe90>,
#   <matplotlib.patches.Wedge at 0x7fcfedf02610>,
#   <matplotlib.patches.Wedge at 0x7fcfedf02e90>],
#  [Text(-0.5134248120007183, 1.0846174267556405, 'Neutral'),
#   Text(0.04308809438043412, -1.0991557742752676, 'Positive'),
#   Text(1.0119050035456565, -0.43133312393006057, 'Negative')],
#  [Text(-0.299497807000419, 0.6326934989407902, '64.1%'),
#   Text(0.02350259693478225, -0.599539513241055, '23.1%'),
#   Text(0.5519481837521762, -0.2352726130527603, '12.8%')])

# %% [markdown]
# # Sentiment Analysis with senti **wordnet**

# %%
data['POS tagged'] =fin_data['Lemma'].apply(token_stop_pos)

# %%
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet as swn

def sentiwordnetanalysis(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue

        # Take the first sense, the most common
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
        #print(swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score())
    if not tokens_count:
        return "Unrecognized"
    if sentiment>=0.5:
        return "Positive"
    if sentiment<=-0.5:
        return "Negative"
    else:
        return "Neutral"

fin_data['SWN analysis'] = data['POS tagged'].apply(sentiwordnetanalysis)
fin_data.head()
# Out:
# [nltk_data] Downloading package sentiwordnet to /root/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
#                                      Cleaned Reviews  \
# 1                                           good app
# 2  Worst experience on the name jio company i ord...
# 3  Very bad delivery Customer care no response Go...
# 4                                               Nice
# 5                                               good
#
#                                                Lemma  Subjectivity  Polarity  \
# 1                                           good app      0.600000       0.7
# 2    Worst experience name jio company order cook...      1.000000      -0.5
# 3    bad delivery Customer care response Goods de...      0.666667      -0.7
# 4                                               Nice      1.000000       0.6
# 5                                               good      0.600000       0.7
#
#    Analysis  Vader Sentiment Vader Analysis SWN analysis
# 1  Positive           0.4404        Neutral     Positive
# 2  Negative          -0.6808       Negative     Negative
# 3  Negative          -0.0772        Neutral      Neutral
# 4  Positive           0.4215        Neutral      Neutral
# 5  Positive           0.4404        Neutral     Positive

# %%
swn_counts= fin_data['SWN analysis'].value_counts()
swn_counts
# Out:
# Positive        86971
# Neutral         70870
# Negative        29761
# Unrecognized    16821
# Name: SWN analysis, dtype: int64

# %%
swn_counts= fin_data['SWN analysis'].value_counts()
plt.figure(figsize=(10, 7))
plt.pie(swn_counts.values, labels = swn_counts.index, explode = (0.1, 0, 0,0), autopct='%1.1f%%', shadow=False)
# plt.legend()
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcfedb8ead0>,
#   <matplotlib.patches.Wedge at 0x7fcfedbb7c90>,
#   <matplotlib.patches.Wedge at 0x7fcfedb75ad0>,
#   <matplotlib.patches.Wedge at 0x7fcfedb75a90>],
#  [Text(0.27849835071123685, 1.1672354812338088, 'Positive'),
#   Text(-0.8948173742990564, -0.6397670409239152, 'Neutral'),
#   Text(0.6178460125750749, -0.9100913716463201, 'Negative'),
#   Text(1.0634500440600292, -0.28120100246749147, 'Unrecognized')],
#  [Text(0.16245737124822146, 0.680887364053055, '42.5%'),
#   Text(-0.4880822041631216, -0.34896384050395374, '34.7%'),
#   Text(0.33700691595004084, -0.49641347544344727, '14.6%'),
#   Text(0.5800636603963795, -0.15338236498226804, '8.2%')])
